# %%
from sklearn.tree import tree
from sklearn_porter import Porter
import numpy as np
import json

from sklearn.model_selection import train_test_split

# %%
with open('./data/y.json') as json_data:
    y = json.load(json_data)

# %%
with open('./data/X.json') as json_data:
    X = json.load(json_data)

# %% [markdown]
# ### Split dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42) ## TODO do K_fold

# %%
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

from sklearn.model_selection import cross_val_score

from sklearn.naive_bayes import GaussianNB
from sklearn import ensemble

# %%
clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=4), n_estimators=200)

# %%
clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)

# %%
## stack-overflow

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

labels = ['non-toxic', 'toxic']
cm = confusion_matrix(y_test, y_pred)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[27818   734]
#  [ 1565  1702]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     28552
#            1       0.70      0.52      0.60      3267
#
#    micro avg       0.93      0.93      0.93     31819
#    macro avg       0.82      0.75      0.78     31819
# weighted avg       0.92      0.93      0.92     31819

# %% [markdown]
# ### Port to javascript

# %%
from sklearn_porter import Porter

# %%
porter = Porter(clf, language='js')

# %%
output = porter.export(embed_data=True)

# %%
print(output)
# Out:
# var AdaBoostClassifier = function() {
#
#     var findMax = function(nums) {
#         var index = 0;
#         for (var i = 0; i < nums.length; i++) {
#             index = nums[i] > nums[index] ? i : index;
#         }
#         return index;
#     };
#
#     var forest = new Array();
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[24] <= 0.5) {
#             if (features[4] <= 1.5) {
#                 classes[0] = 0.19674874679823193;
#                 classes[1] = 0.02473403837390134;
#             } else {
#                 classes[0] = 0.46667819036145747;
#                 classes[1] = 0.020184798152017992;
#             }
#         } else {
#             if (features[29] <= 0.5) {
#                 classes[0] = 0.04236529063280675;
#                 classes[1] = 0.027829721702782237;
#             } else {
#                 classes[0] = 0.19825730314123854;
#                 classes[1] = 0.02320191083803389;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[0] <= 0.5) {
#             if (features[20] <= 1.5) {
#                 classes[0] = 0.1300451518811021;
#                 classes[1] = 0.11251620068230382;
#             } else {
#                 classes[0] = 0.10910865704010277;
#                 classes[1] = 0.03418780476470229;
#             }
#         } else {
#             if (features[76] <= 2.5) {
#                 classes[0] = 0.13625553062521736;
#                 classes[1] = 0.26826499660221015;
#             } else {
#                 classes[0] = 0.12459066045352664;
#                 classes[1] = 0.08503099795086719;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[22] <= 0.5) {
#             if (features[212] <= 0.5) {
#                 classes[0] = 0.3011153459640443;
#                 classes[1] = 0.29136904988285517;
#             } else {
#                 classes[0] = 0.13395101429210846;
#                 classes[1] = 0.07196220850961524;
#             }
#         } else {
#             if (features[23] <= 0.5) {
#                 classes[0] = 0.03934747454966135;
#                 classes[1] = 0.031823814211289686;
#             } else {
#                 classes[0] = 0.02558616519425725;
#                 classes[1] = 0.10484492739627592;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[226] <= 3.5) {
#             if (features[0] <= 3.5) {
#                 classes[0] = 0.3916919096595983;
#                 classes[1] = 0.3832685675971;
#             } else {
#                 classes[0] = 0.04298640347862643;
#                 classes[1] = 0.09298006436278339;
#             }
#         } else {
#             if (features[379] <= 0.5) {
#                 classes[0] = 0.02604876581504481;
#                 classes[1] = 0.015259510266232238;
#             } else {
#                 classes[0] = 0.039272921046682376;
#                 classes[1] = 0.00849185777392518;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[178] <= 0.5) {
#             if (features[47] <= 0.5) {
#                 classes[0] = 0.24368965175008833;
#                 classes[1] = 0.3147752450073095;
#             } else {
#                 classes[0] = 0.17054896359989943;
#                 classes[1] = 0.13850669081969808;
#             }
#         } else {
#             if (features[31] <= 1.5) {
#                 classes[0] = 0.06528412785388306;
#                 classes[1] = 0.028233133516824462;
#             } else {
#                 classes[0] = 0.02047725679610609;
#                 classes[1] = 0.01848493065618156;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[158] <= 0.5) {
#             if (features[38] <= 0.5) {
#                 classes[0] = 0.3221299232292744;
#                 classes[1] = 0.2505476422559653;
#             } else {
#                 classes[0] = 0.10266355023764867;
#                 classes[1] = 0.12891768404690465;
#             }
#         } else {
#             if (features[104] <= 0.5) {
#                 classes[0] = 0.0461526866523165;
#                 classes[1] = 0.05315336616423812;
#             } else {
#                 classes[0] = 0.02905383988082488;
#                 classes[1] = 0.06738130753288701;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[167] <= 0.5) {
#             if (features[23] <= 0.5) {
#                 classes[0] = 0.22283522422018734;
#                 classes[1] = 0.2515623366424791;
#             } else {
#                 classes[0] = 0.021679127272172118;
#                 classes[1] = 0.05218623695208659;
#             }
#         } else {
#             if (features[118] <= 0.5) {
#                 classes[0] = 0.163538456706389;
#                 classes[1] = 0.14502102988872376;
#             } else {
#                 classes[0] = 0.09194719180122668;
#                 classes[1] = 0.051230396516736526;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[0] <= 7.5) {
#             if (features[140] <= 0.5) {
#                 classes[0] = 0.34442632730324063;
#                 classes[1] = 0.3638419730454094;
#             } else {
#                 classes[0] = 0.13498356147919846;
#                 classes[1] = 0.09401109338812116;
#             }
#         } else {
#             if (features[349] <= 2.5) {
#                 classes[0] = 0.017321315494108844;
#                 classes[1] = 0.0415984296945861;
#             } else {
#                 classes[0] = 0.00326879572344204;
#                 classes[1] = 0.0005485038718732761;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[73] <= 0.5) {
#             if (features[76] <= 0.5) {
#                 classes[0] = 0.15527058723224324;
#                 classes[1] = 0.1684714885619931;
#             } else {
#                 classes[0] = 0.19684194852234493;
#                 classes[1] = 0.14451530582228675;
#             }
#         } else {
#             if (features[93] <= 1.5) {
#                 classes[0] = 0.11184179028729278;
#                 classes[1] = 0.16139714449202822;
#             } else {
#                 classes[0] = 0.03604567395813177;
#                 classes[1] = 0.025616061123686484;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[18] <= 0.5) {
#             if (features[327] <= 0.5) {
#                 classes[0] = 0.40914409053680123;
#                 classes[1] = 0.36710192695343397;
#             } else {
#                 classes[0] = 0.0010618894967379172;
#                 classes[1] = 0.007756964004090741;
#             }
#         } else {
#             if (features[217] <= 1.5) {
#                 classes[0] = 0.049462323675176285;
#                 classes[1] = 0.08847267242573872;
#             } else {
#                 classes[0] = 0.04033169629131768;
#                 classes[1] = 0.03666843661673715;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[250] <= 0.5) {
#             if (features[24] <= 0.5) {
#                 classes[0] = 0.30945751924491066;
#                 classes[1] = 0.3359427371207466;
#             } else {
#                 classes[0] = 0.18551167642823413;
#                 classes[1] = 0.14798238331595612;
#             }
#         } else {
#             if (features[285] <= 2.5) {
#                 classes[0] = 0.0043164613343379095;
#                 classes[1] = 0.01591423486370653;
#             } else {
#                 classes[0] = 0.0007143429924897007;
#                 classes[1] = 0.00016064469960627064;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[24] <= 2.5) {
#             if (features[349] <= 0.5) {
#                 classes[0] = 0.44895400409356623;
#                 classes[1] = 0.44473639177246294;
#             } else {
#                 classes[0] = 0.028227939827411563;
#                 classes[1] = 0.012905501301927184;
#             }
#         } else {
#             if (features[22] <= 2.5) {
#                 classes[0] = 0.02079309100292714;
#                 classes[1] = 0.032481265282359104;
#             } else {
#                 classes[0] = 0.0020249650760958207;
#                 classes[1] = 0.009876841643243687;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[162] <= 0.5) {
#             if (features[65] <= 0.5) {
#                 classes[0] = 0.4527668579268868;
#                 classes[1] = 0.44689613798080025;
#             } else {
#                 classes[0] = 0.02523765811380151;
#                 classes[1] = 0.04284589908660427;
#             }
#         } else {
#             if (features[208] <= 0.5) {
#                 classes[0] = 0.011143041544582516;
#                 classes[1] = 0.0027868948323573044;
#             } else {
#                 classes[0] = 0.010852442414733581;
#                 classes[1] = 0.007471068100234307;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[436] <= 0.5) {
#             if (features[35] <= 0.5) {
#                 classes[0] = 0.388611423750025;
#                 classes[1] = 0.37494517571928243;
#             } else {
#                 classes[0] = 0.08435522164925802;
#                 classes[1] = 0.1114193989483915;
#             }
#         } else {
#             if (features[172] <= 16.5) {
#                 classes[0] = 0.026891053255711807;
#                 classes[1] = 0.0124670665378201;
#             } else {
#                 classes[0] = 0.00014230134501162488;
#                 classes[1] = 0.0011683587945104084;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[266] <= 0.5) {
#             if (features[155] <= 0.5) {
#                 classes[0] = 0.32909657120193697;
#                 classes[1] = 0.3480370607217377;
#             } else {
#                 classes[0] = 0.0055407517408857425;
#                 classes[1] = 0.01714512506101549;
#             }
#         } else {
#             if (features[66] <= 9.5) {
#                 classes[0] = 0.158694625737573;
#                 classes[1] = 0.1335501505407288;
#             } else {
#                 classes[0] = 0.006668051319596531;
#                 classes[1] = 0.0012676636765243064;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[149] <= 0.5) {
#             if (features[37] <= 1.5) {
#                 classes[0] = 0.33354511182628477;
#                 classes[1] = 0.2865067582271946;
#             } else {
#                 classes[0] = 0.10384039797056624;
#                 classes[1] = 0.12349114178377922;
#             }
#         } else {
#             if (features[150] <= 0.5) {
#                 classes[0] = 0.05495203396688696;
#                 classes[1] = 0.06306805202320834;
#             } else {
#                 classes[0] = 0.007662456236270714;
#                 classes[1] = 0.026934047965814927;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[189] <= 0.5) {
#             if (features[0] <= 1.5) {
#                 classes[0] = 0.22497280028867883;
#                 classes[1] = 0.22815889161322195;
#             } else {
#                 classes[0] = 0.0775425849681225;
#                 classes[1] = 0.109536518285563;
#             }
#         } else {
#             if (features[131] <= 5.5) {
#                 classes[0] = 0.18569282154710573;
#                 classes[1] = 0.15823505114263262;
#             } else {
#                 classes[0] = 0.011791793196097302;
#                 classes[1] = 0.004069538958584519;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[376] <= 0.5) {
#             if (features[118] <= 0.5) {
#                 classes[0] = 0.36650573170605943;
#                 classes[1] = 0.38208978527492704;
#             } else {
#                 classes[0] = 0.1154268921240963;
#                 classes[1] = 0.08590711394120537;
#             }
#         } else {
#             if (features[172] <= 1.5) {
#                 classes[0] = 0.011754007677007003;
#                 classes[1] = 0.025465318823686217;
#             } else {
#                 classes[0] = 0.006313368492809761;
#                 classes[1] = 0.006537781960183529;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[344] <= 0.5) {
#             if (features[45] <= 0.5) {
#                 classes[0] = 0.15456304340294924;
#                 classes[1] = 0.17544105596504633;
#             } else {
#                 classes[0] = 0.30816961354277356;
#                 classes[1] = 0.26922037301748775;
#             }
#         } else {
#             if (features[436] <= 0.5) {
#                 classes[0] = 0.03427267384407018;
#                 classes[1] = 0.047065329682511634;
#             } else {
#                 classes[0] = 0.0029946692102140594;
#                 classes[1] = 0.008273241334945345;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[52] <= 0.5) {
#             if (features[22] <= 0.5) {
#                 classes[0] = 0.24135517005695126;
#                 classes[1] = 0.19935610362785;
#             } else {
#                 classes[0] = 0.014266666504992276;
#                 classes[1] = 0.026386734189754544;
#             }
#         } else {
#             if (features[80] <= 1.5) {
#                 classes[0] = 0.20038658716646662;
#                 classes[1] = 0.23932650828367813;
#             } else {
#                 classes[0] = 0.0439915762715857;
#                 classes[1] = 0.034930653898713505;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[312] <= 0.5) {
#             if (features[68] <= 0.5) {
#                 classes[0] = 0.3795659985299777;
#                 classes[1] = 0.3772413164045691;
#             } else {
#                 classes[0] = 0.04944213068939153;
#                 classes[1] = 0.030742235582600475;
#             }
#         } else {
#             if (features[22] <= 0.5) {
#                 classes[0] = 0.04555129291478915;
#                 classes[1] = 0.07014889905280706;
#             } else {
#                 classes[0] = 0.02544057786583115;
#                 classes[1] = 0.021867548960020487;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[240] <= 0.5) {
#             if (features[165] <= 0.5) {
#                 classes[0] = 0.33344817971093743;
#                 classes[1] = 0.34549652140935894;
#             } else {
#                 classes[0] = 0.13608963750462483;
#                 classes[1] = 0.10918327483626243;
#             }
#         } else {
#             if (features[246] <= 1.5) {
#                 classes[0] = 0.02613986487569391;
#                 classes[1] = 0.04217863196500805;
#             } else {
#                 classes[0] = 0.004322317908750026;
#                 classes[1] = 0.003141571789365208;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[88] <= 0.5) {
#             if (features[340] <= 0.5) {
#                 classes[0] = 0.4826940901467006;
#                 classes[1] = 0.4663930005686558;
#             } else {
#                 classes[0] = 0.013001638429897454;
#                 classes[1] = 0.022581440126647985;
#             }
#         } else {
#             if (features[139] <= 6.5) {
#                 classes[0] = 0.0035520245239686553;
#                 classes[1] = 0.010757189217892515;
#             } else {
#                 classes[0] = 0.0007522468994320236;
#                 classes[1] = 0.00026837008680566707;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[271] <= 0.5) {
#             if (features[93] <= 0.5) {
#                 classes[0] = 0.35164087289788076;
#                 classes[1] = 0.36530100568910356;
#             } else {
#                 classes[0] = 0.1359382292302332;
#                 classes[1] = 0.11316554987653696;
#             }
#         } else {
#             if (features[0] <= 0.5) {
#                 classes[0] = 0.002465314287812027;
#                 classes[1] = 0.007834977006657124;
#             } else {
#                 classes[0] = 0.009955583584070405;
#                 classes[1] = 0.013698467427701316;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[86] <= 0.5) {
#             if (features[146] <= 0.5) {
#                 classes[0] = 0.32157276071637764;
#                 classes[1] = 0.28271831451455537;
#             } else {
#                 classes[0] = 0.028247030573812983;
#                 classes[1] = 0.0413266365706758;
#             }
#         } else {
#             if (features[207] <= 0.5) {
#                 classes[0] = 0.024508992947760242;
#                 classes[1] = 0.04899096307580138;
#             } else {
#                 classes[0] = 0.1256712157620481;
#                 classes[1] = 0.1269640858389644;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[156] <= 0.5) {
#             if (features[226] <= 0.5) {
#                 classes[0] = 0.23131376078705895;
#                 classes[1] = 0.2381867315093244;
#             } else {
#                 classes[0] = 0.11430358502764021;
#                 classes[1] = 0.08412054246020884;
#             }
#         } else {
#             if (features[234] <= 0.5) {
#                 classes[0] = 0.03793070046016659;
#                 classes[1] = 0.059481213110581965;
#             } else {
#                 classes[0] = 0.11645195372512927;
#                 classes[1] = 0.11821151291988352;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[111] <= 0.5) {
#             if (features[122] <= 0.5) {
#                 classes[0] = 0.2772432247726871;
#                 classes[1] = 0.24435965049642508;
#             } else {
#                 classes[0] = 0.03964887644421293;
#                 classes[1] = 0.047936613190784905;
#             }
#         } else {
#             if (features[85] <= 0.5) {
#                 classes[0] = 0.05215697738152141;
#                 classes[1] = 0.07448292267901506;
#             } else {
#                 classes[0] = 0.13095092140158668;
#                 classes[1] = 0.13322081363377108;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[221] <= 0.5) {
#             if (features[117] <= 0.5) {
#                 classes[0] = 0.28068478414060966;
#                 classes[1] = 0.27834785666878215;
#             } else {
#                 classes[0] = 0.07300579727538961;
#                 classes[1] = 0.09644259940985976;
#             }
#         } else {
#             if (features[76] <= 2.5) {
#                 classes[0] = 0.07920749048148115;
#                 classes[1] = 0.056029645610757406;
#             } else {
#                 classes[0] = 0.06710192810251144;
#                 classes[1] = 0.06917989831060317;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[217] <= 0.5) {
#             if (features[23] <= 0.5) {
#                 classes[0] = 0.2740080551627575;
#                 classes[1] = 0.2809981483848142;
#             } else {
#                 classes[0] = 0.03508726771827828;
#                 classes[1] = 0.05117361913420013;
#             }
#         } else {
#             if (features[143] <= 0.5) {
#                 classes[0] = 0.16000912522513952;
#                 classes[1] = 0.129039791921451;
#             } else {
#                 classes[0] = 0.030895551893823734;
#                 classes[1] = 0.03878844055953134;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[24] <= 0.5) {
#             if (features[23] <= 0.5) {
#                 classes[0] = 0.2744614346804547;
#                 classes[1] = 0.3140982286705314;
#             } else {
#                 classes[0] = 0.04416469183100225;
#                 classes[1] = 0.02849813067691833;
#             }
#         } else {
#             if (features[29] <= 0.5) {
#                 classes[0] = 0.07344124026694175;
#                 classes[1] = 0.03608365462114114;
#             } else {
#                 classes[0] = 0.1079326332216061;
#                 classes[1] = 0.12131998603140742;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[41] <= 0.5) {
#             if (features[23] <= 0.5) {
#                 classes[0] = 0.30373768451142624;
#                 classes[1] = 0.3017135884038891;
#             } else {
#                 classes[0] = 0.04468329253925325;
#                 classes[1] = 0.06708708121007302;
#             }
#         } else {
#             if (features[226] <= 3.5) {
#                 classes[0] = 0.12678850396791233;
#                 classes[1] = 0.1005379381854839;
#             } else {
#                 classes[0] = 0.024790518981404344;
#                 classes[1] = 0.03066139220055605;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[27] <= 2.5) {
#             if (features[144] <= 0.5) {
#                 classes[0] = 0.39654494541747526;
#                 classes[1] = 0.3927397670148923;
#             } else {
#                 classes[0] = 0.055535298062606944;
#                 classes[1] = 0.07324820278947919;
#             }
#         } else {
#             if (features[147] <= 12.5) {
#                 classes[0] = 0.04706487309175829;
#                 classes[1] = 0.031643567582540694;
#             } else {
#                 classes[0] = 0.0008548834281576195;
#                 classes[1] = 0.0023684626130836875;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[142] <= 0.5) {
#             if (features[0] <= 14.5) {
#                 classes[0] = 0.4201203433764545;
#                 classes[1] = 0.4302733310364757;
#             } else {
#                 classes[0] = 0.0020600316518693965;
#                 classes[1] = 0.006667912966934215;
#             }
#         } else {
#             if (features[75] <= 1.5) {
#                 classes[0] = 0.044298191372877056;
#                 classes[1] = 0.029632556800897273;
#             } else {
#                 classes[0] = 0.033521433598796856;
#                 classes[1] = 0.03342619919569084;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[167] <= 4.5) {
#             if (features[4] <= 1.5) {
#                 classes[0] = 0.1916699722224716;
#                 classes[1] = 0.17313067257330272;
#             } else {
#                 classes[0] = 0.2776482143527492;
#                 classes[1] = 0.3063019310292929;
#             }
#         } else {
#             if (features[0] <= 26.5) {
#                 classes[0] = 0.029624221423883174;
#                 classes[1] = 0.018253862458960865;
#             } else {
#                 classes[0] = 0.0010575920009034242;
#                 classes[1] = 0.0023135339384423984;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[8] <= 0.5) {
#             if (features[24] <= 1.5) {
#                 classes[0] = 0.17355020382751873;
#                 classes[1] = 0.18587050636423408;
#             } else {
#                 classes[0] = 0.006975947272352721;
#                 classes[1] = 0.0159443161070382;
#             }
#         } else {
#             if (features[89] <= 0.5) {
#                 classes[0] = 0.22218741398983027;
#                 classes[1] = 0.1890151915236141;
#             } else {
#                 classes[0] = 0.0972864349102962;
#                 classes[1] = 0.10916998600511643;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[314] <= 0.5) {
#             if (features[37] <= 3.5) {
#                 classes[0] = 0.36920750532473273;
#                 classes[1] = 0.3737983066477312;
#             } else {
#                 classes[0] = 0.025227145022173103;
#                 classes[1] = 0.03687571819537922;
#             }
#         } else {
#             if (features[68] <= 4.5) {
#                 classes[0] = 0.10324683426495222;
#                 classes[1] = 0.08902505385139756;
#             } else {
#                 classes[0] = 0.0023185153881473135;
#                 classes[1] = 0.00030092130549235033;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[208] <= 0.5) {
#             if (features[343] <= 2.5) {
#                 classes[0] = 0.36575623651349043;
#                 classes[1] = 0.34504903296415673;
#             } else {
#                 classes[0] = 0.0008655564483266727;
#                 classes[1] = 0.003709121539648353;
#             }
#         } else {
#             if (features[24] <= 0.5) {
#                 classes[0] = 0.0683351879348348;
#                 classes[1] = 0.09017125675609972;
#             } else {
#                 classes[0] = 0.06504301910333761;
#                 classes[1] = 0.06107058874009934;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[151] <= 0.5) {
#             if (features[23] <= 0.5) {
#                 classes[0] = 0.2878780181277071;
#                 classes[1] = 0.29429177583530486;
#             } else {
#                 classes[0] = 0.02081083545520315;
#                 classes[1] = 0.03425224569299611;
#             }
#         } else {
#             if (features[0] <= 2.5) {
#                 classes[0] = 0.1228416631705275;
#                 classes[1] = 0.09794823969629349;
#             } else {
#                 classes[0] = 0.06846948324656754;
#                 classes[1] = 0.07350773877540195;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[354] <= 0.5) {
#             if (features[159] <= 0.5) {
#                 classes[0] = 0.37130143617458217;
#                 classes[1] = 0.3974029715339851;
#             } else {
#                 classes[0] = 0.040987693052778336;
#                 classes[1] = 0.02949934496460288;
#             }
#         } else {
#             if (features[226] <= 3.5) {
#                 classes[0] = 0.07106656672063046;
#                 classes[1] = 0.05056070636463068;
#             } else {
#                 classes[0] = 0.016644304052004563;
#                 classes[1] = 0.022536977136783185;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[60] <= 0.5) {
#             if (features[295] <= 0.5) {
#                 classes[0] = 0.2506998324073163;
#                 classes[1] = 0.24914531391349826;
#             } else {
#                 classes[0] = 0.07465474218264406;
#                 classes[1] = 0.05725860219065936;
#             }
#         } else {
#             if (features[0] <= 0.5) {
#                 classes[0] = 0.04141440093093467;
#                 classes[1] = 0.06084687376162606;
#             } else {
#                 classes[0] = 0.1332310244791067;
#                 classes[1] = 0.13274921013421304;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[191] <= 0.5) {
#             if (features[272] <= 0.5) {
#                 classes[0] = 0.3591349734827209;
#                 classes[1] = 0.3530729862510614;
#             } else {
#                 classes[0] = 0.03549903891665036;
#                 classes[1] = 0.024910632312269112;
#             }
#         } else {
#             if (features[243] <= 0.5) {
#                 classes[0] = 0.034544657494308545;
#                 classes[1] = 0.05257457779473084;
#             } else {
#                 classes[0] = 0.07082133010632378;
#                 classes[1] = 0.0694418036419385;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[37] <= 0.5) {
#             if (features[65] <= 0.5) {
#                 classes[0] = 0.22476181786510852;
#                 classes[1] = 0.1999283218458453;
#             } else {
#                 classes[0] = 0.006779897059407366;
#                 classes[1] = 0.011818601720801323;
#             }
#         } else {
#             if (features[4] <= 6.5) {
#                 classes[0] = 0.1557523434856103;
#                 classes[1] = 0.18123211205123124;
#             } else {
#                 classes[0] = 0.1127059415898718;
#                 classes[1] = 0.10702096438212404;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[327] <= 0.5) {
#             if (features[476] <= 0.5) {
#                 classes[0] = 0.495380222080287;
#                 classes[1] = 0.4889291369533234;
#             } else {
#                 classes[0] = 0.00047037566715917104;
#                 classes[1] = 0.0025882960197384126;
#             }
#         } else {
#             if (features[18] <= 0.5) {
#                 classes[0] = 0.003038278322928596;
#                 classes[1] = 0.003749616360582129;
#             } else {
#                 classes[0] = 0.0011111239296265369;
#                 classes[1] = 0.00473295066635865;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[4] <= 0.5) {
#             if (features[24] <= 0.5) {
#                 classes[0] = 0.07381655307527683;
#                 classes[1] = 0.07816072894402981;
#             } else {
#                 classes[0] = 0.015110256691607107;
#                 classes[1] = 0.025294135607476783;
#             }
#         } else {
#             if (features[71] <= 0.5) {
#                 classes[0] = 0.2241027958460462;
#                 classes[1] = 0.1938709104583944;
#             } else {
#                 classes[0] = 0.18697039438707078;
#                 classes[1] = 0.20267422499009877;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[221] <= 4.5) {
#             if (features[158] <= 0.5) {
#                 classes[0] = 0.41132223913843535;
#                 classes[1] = 0.40146029277392653;
#             } else {
#                 classes[0] = 0.07925048761658426;
#                 classes[1] = 0.09386961514774639;
#             }
#         } else {
#             if (features[28] <= 36.5) {
#                 classes[0] = 0.008492737240505636;
#                 classes[1] = 0.003134066641191088;
#             } else {
#                 classes[0] = 0.0009345360044763754;
#                 classes[1] = 0.00153602543713685;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[223] <= 0.5) {
#             if (features[331] <= 0.5) {
#                 classes[0] = 0.40793891932953125;
#                 classes[1] = 0.4178852333351551;
#             } else {
#                 classes[0] = 0.003611551949385794;
#                 classes[1] = 0.007496072242748291;
#             }
#         } else {
#             if (features[212] <= 0.5) {
#                 classes[0] = 0.049215414370240865;
#                 classes[1] = 0.032466235220240745;
#             } else {
#                 classes[0] = 0.039234114350845534;
#                 classes[1] = 0.04215245920185371;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[461] <= 0.5) {
#             if (features[122] <= 0.5) {
#                 classes[0] = 0.39855095623545245;
#                 classes[1] = 0.3897976810186376;
#             } else {
#                 classes[0] = 0.08638038642853173;
#                 classes[1] = 0.100856386585177;
#             }
#         } else {
#             if (features[548] <= 0.5) {
#                 classes[0] = 0.014976358439872814;
#                 classes[1] = 0.008649517965859665;
#             } else {
#                 classes[0] = 9.229889614698091e-05;
#                 classes[1] = 0.0006964144303293778;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[398] <= 0.5) {
#             if (features[13] <= 52.5) {
#                 classes[0] = 0.4514624105717192;
#                 classes[1] = 0.46121854589122663;
#             } else {
#                 classes[0] = 6.729268844231376e-05;
#                 classes[1] = 0.0014616885107031814;
#             }
#         } else {
#             if (features[0] <= 1.5) {
#                 classes[0] = 0.022386590940092647;
#                 classes[1] = 0.012516367878956415;
#             } else {
#                 classes[0] = 0.02608370579973796;
#                 classes[1] = 0.02480339771911708;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[301] <= 0.5) {
#             if (features[484] <= 0.5) {
#                 classes[0] = 0.4846252578053085;
#                 classes[1] = 0.4917795846793031;
#             } else {
#                 classes[0] = 0.004339886795260734;
#                 classes[1] = 0.001853654661149213;
#             }
#         } else {
#             if (features[71] <= 8.5) {
#                 classes[0] = 0.009949285148958709;
#                 classes[1] = 0.006366760659547774;
#             } else {
#                 classes[0] = 0.001085570250474919;
#                 classes[1] = 0.0;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[22] <= 3.5) {
#             if (features[346] <= 5.5) {
#                 classes[0] = 0.49732155147970847;
#                 classes[1] = 0.4925224721978322;
#             } else {
#                 classes[0] = 0.0008283640254442295;
#                 classes[1] = 0.0029106067508725573;
#             }
#         } else {
#             if (features[151] <= 5.5) {
#                 classes[0] = 0.0007617052432038964;
#                 classes[1] = 0.0037651696233789826;
#             } else {
#                 classes[0] = 0.00108837925974679;
#                 classes[1] = 0.0008017514198137571;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[164] <= 0.5) {
#             if (features[44] <= 0.5) {
#                 classes[0] = 0.26647226555832165;
#                 classes[1] = 0.2623221245986859;
#             } else {
#                 classes[0] = 0.06268531198730223;
#                 classes[1] = 0.08254807544654741;
#             }
#         } else {
#             if (features[23] <= 0.5) {
#                 classes[0] = 0.11383231495988093;
#                 classes[1] = 0.1142434579403776;
#             } else {
#                 classes[0] = 0.0570101074944971;
#                 classes[1] = 0.04088634201438684;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[12] <= 0.5) {
#             if (features[214] <= 0.5) {
#                 classes[0] = 0.22367170447798354;
#                 classes[1] = 0.21711812332661418;
#             } else {
#                 classes[0] = 0.031023996268967714;
#                 classes[1] = 0.019780687653178093;
#             }
#         } else {
#             if (features[0] <= 0.5) {
#                 classes[0] = 0.06811867533539169;
#                 classes[1] = 0.08459529066657251;
#             } else {
#                 classes[0] = 0.1771856239176572;
#                 classes[1] = 0.17850589835363598;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[0] <= 1.5) {
#             if (features[172] <= 0.5) {
#                 classes[0] = 0.251561804875542;
#                 classes[1] = 0.24993844714923497;
#             } else {
#                 classes[0] = 0.06666203089168617;
#                 classes[1] = 0.05168329166189715;
#             }
#         } else {
#             if (features[87] <= 0.5) {
#                 classes[0] = 0.11099134967992265;
#                 classes[1] = 0.13240189454768586;
#             } else {
#                 classes[0] = 0.07078481455285075;
#                 classes[1] = 0.06597636664118094;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[52] <= 2.5) {
#             if (features[319] <= 0.5) {
#                 classes[0] = 0.39170881721630685;
#                 classes[1] = 0.3887934009255328;
#             } else {
#                 classes[0] = 0.03852928174653768;
#                 classes[1] = 0.02777896482893619;
#             }
#         } else {
#             if (features[137] <= 4.5) {
#                 classes[0] = 0.06833382184593442;
#                 classes[1] = 0.0830743122762941;
#             } else {
#                 classes[0] = 0.0014280791912312056;
#                 classes[1] = 0.0003533219692372732;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[40] <= 0.5) {
#             if (features[104] <= 0.5) {
#                 classes[0] = 0.1968638193865342;
#                 classes[1] = 0.20259443050465972;
#             } else {
#                 classes[0] = 0.02238279056534056;
#                 classes[1] = 0.03226719914641522;
#             }
#         } else {
#             if (features[167] <= 0.5) {
#                 classes[0] = 0.12486243235004596;
#                 classes[1] = 0.10230409916314319;
#             } else {
#                 classes[0] = 0.15589095769807437;
#                 classes[1] = 0.1628342711857874;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[96] <= 0.5) {
#             if (features[19] <= 0.5) {
#                 classes[0] = 0.17828554346912992;
#                 classes[1] = 0.16731153290672499;
#             } else {
#                 classes[0] = 0.23146912720940946;
#                 classes[1] = 0.25489158867795964;
#             }
#         } else {
#             if (features[203] <= 8.5) {
#                 classes[0] = 0.08980153984759469;
#                 classes[1] = 0.07597549518916231;
#             } else {
#                 classes[0] = 0.000443789473866386;
#                 classes[1] = 0.0018213832261538307;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[33] <= 1.5) {
#             if (features[305] <= 0.5) {
#                 classes[0] = 0.20363204852619193;
#                 classes[1] = 0.2144850842544253;
#             } else {
#                 classes[0] = 0.00548082978885007;
#                 classes[1] = 0.011058399438377291;
#             }
#         } else {
#             if (features[16] <= 0.5) {
#                 classes[0] = 0.08222148913831033;
#                 classes[1] = 0.06656965866030476;
#             } else {
#                 classes[0] = 0.20866563254664555;
#                 classes[1] = 0.20788685764689196;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[181] <= 2.5) {
#             if (features[183] <= 0.5) {
#                 classes[0] = 0.4853558084771974;
#                 classes[1] = 0.48759659546167544;
#             } else {
#                 classes[0] = 0.012624834463130077;
#                 classes[1] = 0.007952781482380072;
#             }
#         } else {
#             if (features[123] <= 2.5) {
#                 classes[0] = 0.0012163674483823008;
#                 classes[1] = 0.004124131141594895;
#             } else {
#                 classes[0] = 0.0008029896112848563;
#                 classes[1] = 0.00032649191434949953;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[38] <= 1.5) {
#             if (features[164] <= 3.5) {
#                 classes[0] = 0.4388785931174016;
#                 classes[1] = 0.4327677531958729;
#             } else {
#                 classes[0] = 0.006306253990904295;
#                 classes[1] = 0.0028042477132104314;
#             }
#         } else {
#             if (features[317] <= 0.5) {
#                 classes[0] = 0.04425150594441551;
#                 classes[1] = 0.05686526346195593;
#             } else {
#                 classes[0] = 0.010563646947275573;
#                 classes[1] = 0.007562735628957476;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[158] <= 2.5) {
#             if (features[5] <= 10.5) {
#                 classes[0] = 0.454963242445125;
#                 classes[1] = 0.46006642878743736;
#             } else {
#                 classes[0] = 0.03752429238288383;
#                 classes[1] = 0.027975615589031583;
#             }
#         } else {
#             if (features[102] <= 3.5) {
#                 classes[0] = 0.0028202616357737163;
#                 classes[1] = 0.0020164651031327457;
#             } else {
#                 classes[0] = 0.004692203536220743;
#                 classes[1] = 0.009941490520395594;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[129] <= 1.5) {
#             if (features[125] <= 0.5) {
#                 classes[0] = 0.40759679372814733;
#                 classes[1] = 0.41572111110162063;
#             } else {
#                 classes[0] = 0.08530226075199425;
#                 classes[1] = 0.07289094077329338;
#             }
#         } else {
#             if (features[318] <= 2.5) {
#                 classes[0] = 0.004591020335630225;
#                 classes[1] = 0.0049816980154750515;
#             } else {
#                 classes[0] = 0.0025099251842262285;
#                 classes[1] = 0.006406250109609551;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[261] <= 0.5) {
#             if (features[233] <= 3.5) {
#                 classes[0] = 0.3264862317947176;
#                 classes[1] = 0.3091271084333928;
#             } else {
#                 classes[0] = 0.0021010045335981766;
#                 classes[1] = 0.004824361586680913;
#             }
#         } else {
#             if (features[13] <= 34.5) {
#                 classes[0] = 0.169587230494974;
#                 classes[1] = 0.18566516018757587;
#             } else {
#                 classes[0] = 0.0018255331767076538;
#                 classes[1] = 0.00038336979235117035;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[63] <= 12.5) {
#             if (features[294] <= 1.5) {
#                 classes[0] = 0.4210864717103096;
#                 classes[1] = 0.4313086178668158;
#             } else {
#                 classes[0] = 0.07842930447744842;
#                 classes[1] = 0.06667325665134949;
#             }
#         } else {
#             if (features[262] <= 3.5) {
#                 classes[0] = 0.0003392354046334988;
#                 classes[1] = 0.0019713668522950093;
#             } else {
#                 classes[0] = 0.00014498840761526254;
#                 classes[1] = 4.675862953674432e-05;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[115] <= 0.5) {
#             if (features[130] <= 0.5) {
#                 classes[0] = 0.4060320200478896;
#                 classes[1] = 0.3864423335953133;
#             } else {
#                 classes[0] = 0.050230101487487196;
#                 classes[1] = 0.06006850833152976;
#             }
#         } else {
#             if (features[46] <= 3.5) {
#                 classes[0] = 0.042990834345948394;
#                 classes[1] = 0.05348915807315824;
#             } else {
#                 classes[0] = 0.0007470441186725411;
#                 classes[1] = 0.0;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[268] <= 0.5) {
#             if (features[65] <= 0.5) {
#                 classes[0] = 0.4135898836411597;
#                 classes[1] = 0.41756653050020526;
#             } else {
#                 classes[0] = 0.011487242617526507;
#                 classes[1] = 0.01861368361110713;
#             }
#         } else {
#             if (features[308] <= 0.5) {
#                 classes[0] = 0.07081002823136177;
#                 classes[1] = 0.0574575946907582;
#             } else {
#                 classes[0] = 0.004112845515532967;
#                 classes[1] = 0.006362191192354005;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[276] <= 0.5) {
#             if (features[149] <= 1.5) {
#                 classes[0] = 0.4361199175881225;
# ...
#                 classes[1] = 0.04107187189297765;
#             } else {
#                 classes[0] = 0.020317176957596692;
#                 classes[1] = 0.022192214937636748;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[360] <= 1.5) {
#             if (features[99] <= 1.5) {
#                 classes[0] = 0.49733802514080533;
#                 classes[1] = 0.4990107346090644;
#             } else {
#                 classes[0] = 0.0005535256392491652;
#                 classes[1] = 6.152287696121392e-05;
#             }
#         } else {
#             if (features[204] <= 1.5) {
#                 classes[0] = 0.0019553175181108388;
#                 classes[1] = 0.0005307038026630264;
#             } else {
#                 classes[0] = 0.000153131701837255;
#                 classes[1] = 0.00039703871131126917;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[346] <= 7.5) {
#             if (features[353] <= 2.5) {
#                 classes[0] = 0.49804949753219047;
#                 classes[1] = 0.498395191719261;
#             } else {
#                 classes[0] = 0.0017033695571489391;
#                 classes[1] = 0.0006820147911141958;
#             }
#         } else {
#             if (features[42] <= 8.5) {
#                 classes[0] = 9.311289648574358e-05;
#                 classes[1] = 0.0008859743401763236;
#             } else {
#                 classes[0] = 0.00015402001417496493;
#                 classes[1] = 3.681914944914261e-05;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[306] <= 1.5) {
#             if (features[355] <= 3.5) {
#                 classes[0] = 0.4818358169236931;
#                 classes[1] = 0.48085583292018647;
#             } else {
#                 classes[0] = 0.005553017542371882;
#                 classes[1] = 0.0029623792198477704;
#             }
#         } else {
#             if (features[233] <= 0.5) {
#                 classes[0] = 0.0060164659639580995;
#                 classes[1] = 0.005270350803807273;
#             } else {
#                 classes[0] = 0.006594699569980288;
#                 classes[1] = 0.010911437056159018;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[402] <= 6.5) {
#             if (features[99] <= 0.5) {
#                 classes[0] = 0.4962998638487637;
#                 classes[1] = 0.4951240645782943;
#             } else {
#                 classes[0] = 0.0029170155300009934;
#                 classes[1] = 0.004713854004647395;
#             }
#         } else {
#             if (features[404] <= 3.5) {
#                 classes[0] = 0.0007823566696048763;
#                 classes[1] = 0.00010127202157778597;
#             } else {
#                 classes[0] = 7.639516231800412e-07;
#                 classes[1] = 6.08093954829203e-05;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[74] <= 0.5) {
#             if (features[59] <= 0.5) {
#                 classes[0] = 0.3384544720384032;
#                 classes[1] = 0.3369026615475614;
#             } else {
#                 classes[0] = 0.05811300909637762;
#                 classes[1] = 0.06768622479756244;
#             }
#         } else {
#             if (features[394] <= 0.5) {
#                 classes[0] = 0.1020000020763047;
#                 classes[1] = 0.09258429744640839;
#             } else {
#                 classes[0] = 0.0014325167889226017;
#                 classes[1] = 0.002826816208466115;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[404] <= 1.5) {
#             if (features[156] <= 6.5) {
#                 classes[0] = 0.49460863109064324;
#                 classes[1] = 0.49479485485210495;
#             } else {
#                 classes[0] = 0.0015805476114914543;
#                 classes[1] = 0.002941860626632834;
#             }
#         } else {
#             if (features[11] <= 6.5) {
#                 classes[0] = 0.0027768939907483483;
#                 classes[1] = 0.0008307549418743939;
#             } else {
#                 classes[0] = 0.00103392730711489;
#                 classes[1] = 0.001432529579392669;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[41] <= 4.5) {
#             if (features[395] <= 0.5) {
#                 classes[0] = 0.47028803965431987;
#                 classes[1] = 0.4765465477286895;
#             } else {
#                 classes[0] = 0.024052343665428497;
#                 classes[1] = 0.019965057862036895;
#             }
#         } else {
#             if (features[209] <= 2.5) {
#                 classes[0] = 0.00524072789942197;
#                 classes[1] = 0.0027188971207133673;
#             } else {
#                 classes[0] = 0.00041888878083149383;
#                 classes[1] = 0.0007694972885555842;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[98] <= 29.5) {
#             if (features[140] <= 0.5) {
#                 classes[0] = 0.38673289389120835;
#                 classes[1] = 0.37814349292721494;
#             } else {
#                 classes[0] = 0.11324540354673827;
#                 classes[1] = 0.12141577816935863;
#             }
#         } else {
#             if (features[241] <= 0.5) {
#                 classes[0] = 9.858235735842636e-06;
#                 classes[1] = 0.00043913084481100444;
#             } else {
#                 classes[0] = 1.1844326314843158e-05;
#                 classes[1] = 1.598058617531436e-06;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[140] <= 1.5) {
#             if (features[550] <= 0.5) {
#                 classes[0] = 0.4554407437536905;
#                 classes[1] = 0.4622814168388847;
#             } else {
#                 classes[0] = 0.0018237596086629314;
#                 classes[1] = 0.0006622934984149324;
#             }
#         } else {
#             if (features[136] <= 0.5) {
#                 classes[0] = 0.035780532849090864;
#                 classes[1] = 0.027917524848515625;
#             } else {
#                 classes[0] = 0.006954963788556436;
#                 classes[1] = 0.009138764814183598;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[658] <= 0.5) {
#             if (features[19] <= 1.5) {
#                 classes[0] = 0.3228079901588121;
#                 classes[1] = 0.3141609427172644;
#             } else {
#                 classes[0] = 0.17609603948989938;
#                 classes[1] = 0.1854692719099593;
#             }
#         } else {
#             if (features[459] <= 0.5) {
#                 classes[0] = 0.0010720575419550641;
#                 classes[1] = 0.0002137101730206957;
#             } else {
#                 classes[0] = 2.3912809330327973e-05;
#                 classes[1] = 0.00015607519975544925;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[85] <= 1.5) {
#             if (features[443] <= 0.5) {
#                 classes[0] = 0.35305095977258555;
#                 classes[1] = 0.36543647163711807;
#             } else {
#                 classes[0] = 0.005866011617211815;
#                 classes[1] = 0.003487335361838758;
#             }
#         } else {
#             if (features[86] <= 0.5) {
#                 classes[0] = 0.06849529941645592;
#                 classes[1] = 0.055005953936207046;
#             } else {
#                 classes[0] = 0.0725877291937462;
#                 classes[1] = 0.07607023906483529;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[15] <= 16.5) {
#             if (features[73] <= 3.5) {
#                 classes[0] = 0.48857859645821433;
#                 classes[1] = 0.4865037256526119;
#             } else {
#                 classes[0] = 0.009366151308317503;
#                 classes[1] = 0.012560367588805067;
#             }
#         } else {
#             if (features[69] <= 23.5) {
#                 classes[0] = 0.002028779047941957;
#                 classes[1] = 0.0007443029802293642;
#             } else {
#                 classes[0] = 2.647318553207797e-05;
#                 classes[1] = 0.0001916037783518435;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[20] <= 8.5) {
#             if (features[139] <= 1.5) {
#                 classes[0] = 0.392323045270485;
#                 classes[1] = 0.3885956924670923;
#             } else {
#                 classes[0] = 0.07253005302478673;
#                 classes[1] = 0.08171863171518791;
#             }
#         } else {
#             if (features[120] <= 1.5) {
#                 classes[0] = 0.01627445972029397;
#                 classes[1] = 0.010485988206014008;
#             } else {
#                 classes[0] = 0.0188724419844336;
#                 classes[1] = 0.019199687611706723;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[233] <= 13.5) {
#             if (features[98] <= 1.5) {
#                 classes[0] = 0.43826912269392776;
#                 classes[1] = 0.4438909861726475;
#             } else {
#                 classes[0] = 0.06137336724139465;
#                 classes[1] = 0.05493102686427881;
#             }
#         } else {
#             if (features[143] <= 0.5) {
#                 classes[0] = 0.00018604655588077624;
#                 classes[1] = 0.0011202824626361074;
#             } else {
#                 classes[0] = 0.00017146350879320267;
#                 classes[1] = 5.770450043775337e-05;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[37] <= 2.5) {
#             if (features[5] <= 8.5) {
#                 classes[0] = 0.4079935991735784;
#                 classes[1] = 0.40509442535201057;
#             } else {
#                 classes[0] = 0.015050852268831698;
#                 classes[1] = 0.010481786626754771;
#             }
#         } else {
#             if (features[248] <= 0.5) {
#                 classes[0] = 0.046036353286152534;
#                 classes[1] = 0.04564322613781823;
#             } else {
#                 classes[0] = 0.030919195271431422;
#                 classes[1] = 0.03878056188341574;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[196] <= 0.5) {
#             if (features[333] <= 0.5) {
#                 classes[0] = 0.4195756212384766;
#                 classes[1] = 0.42773382035157564;
#             } else {
#                 classes[0] = 0.002014714303444777;
#                 classes[1] = 0.0006363073129550305;
#             }
#         } else {
#             if (features[76] <= 0.5) {
#                 classes[0] = 0.01822161323788315;
#                 classes[1] = 0.01179896124144462;
#             } else {
#                 classes[0] = 0.06018805122019802;
#                 classes[1] = 0.05983091109402101;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[468] <= 0.5) {
#             if (features[76] <= 7.5) {
#                 classes[0] = 0.47133484442576307;
#                 classes[1] = 0.47744048457652605;
#             } else {
#                 classes[0] = 0.019729272692174595;
#                 classes[1] = 0.01596491761112713;
#             }
#         } else {
#             if (features[8] <= 5.5) {
#                 classes[0] = 0.007086939766543654;
#                 classes[1] = 0.003955561186325346;
#             } else {
#                 classes[0] = 0.0018489431155169662;
#                 classes[1] = 0.002639036626021786;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[0] <= 5.5) {
#             if (features[0] <= 3.5) {
#                 classes[0] = 0.4216645428253871;
#                 classes[1] = 0.4236898853351045;
#             } else {
#                 classes[0] = 0.042812908414423506;
#                 classes[1] = 0.0348925727372177;
#             }
#         } else {
#             if (features[13] <= 1.5) {
#                 classes[0] = 0.0046789661512443735;
#                 classes[1] = 0.008012334005201113;
#             } else {
#                 classes[0] = 0.030843582608938592;
#                 classes[1] = 0.03340520792247632;
#             }
#         }
#         return classes;
#     });
#
#     forest.push(function(features) {
#         var classes = new Array(2);
#         if (features[221] <= 0.5) {
#             if (features[122] <= 0.5) {
#                 classes[0] = 0.34314979100985155;
#                 classes[1] = 0.3269738012625164;
#             } else {
#                 classes[0] = 0.03652080145562178;
#                 classes[1] = 0.04332854228782425;
#             }
#         } else {
#             if (features[18] <= 0.5) {
#                 classes[0] = 0.07388248876989058;
#                 classes[1] = 0.08711991340625114;
#             } else {
#                 classes[0] = 0.04644691876463709;
#                 classes[1] = 0.04257774304340516;
#             }
#         }
#         return classes;
#     });
#
#     this.predict = function(features) {
#         var n_estimators = forest.length;
#         var preds = new Array(n_estimators);
#         var n_classes = 2;
#         var classes = new Array(n_classes).fill(0.);
#         var normalizer, sum, idx, val;
#         var i, j;
#
#         for (i = 0; i < n_estimators; i++) {
#             preds[i] = forest[i](features);
#         }
#         for (i = 0; i < n_estimators; i++) {
#             normalizer = 0.;
#             for (j = 0; j < n_classes; j++) {
#                 normalizer += preds[i][j];
#             }
#             if (normalizer == 0.) {
#                 normalizer = 1.0;
#             }
#             for (j = 0; j < n_classes; j++) {
#                 preds[i][j] = preds[i][j] / normalizer;
#                 if (preds[i][j] <= 2.2204460492503131e-16) {
#                     preds[i][j] = 2.2204460492503131e-16;
#                 }
#                 preds[i][j] = Math.log(preds[i][j]);
#             }
#             sum = 0.0;
#             for (j = 0; j < n_classes; j++) {
#                 sum += preds[i][j];
#             }
#             for (j = 0; j < n_classes; j++) {
#                 preds[i][j] = (n_classes - 1) * (preds[i][j] - (1. / n_classes) * sum);
#             }
#         }
#         for (i = 0; i < n_estimators; i++) {
#             for (j = 0; j < n_classes; j++) {
#                 classes[j] += preds[i][j];
#             }
#         }
#
#         return findMax(classes);
#     };
# };
#
# if (typeof process !== 'undefined' && typeof process.argv !== 'undefined') {
#     if (process.argv.length - 2 === 717) {
#
#         // Features:
#         var features = process.argv.slice(2);
#
#         // Prediction:
#         var clf = new AdaBoostClassifier();
#         var prediction = clf.predict(features);
#         console.log(prediction);
#
#     }
# }
